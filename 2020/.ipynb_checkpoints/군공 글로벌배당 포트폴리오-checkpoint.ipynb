# %%
# %matplotlib inline

import pandas as pd
import scipy as sp
from scipy.optimize import fmin_slsqp
import numpy as np
from IPython.core.debugger import set_trace
from tqdm import tqdm_notebook

# %% [markdown]
# # 초기화

# %%
univ = pd.read_excel('simul_20191210.xlsx', sheet_name='category')[:-2]; univ;

# %%
regions = univ.region.unique(); regions
# Out:
# array(['US', 'Global', 'EM', 'DM'], dtype=object)

# %%
cats = univ.category.unique(); cats
# Out:
# array(['US_HD', 'US_HD_LV', 'US_DG', 'US_DG_QL', 'US_PS', 'Global', 'EM',
#        'DM'], dtype=object)

# %%
prices = pd.read_excel('simul_20191210.xlsx', sheet_name='price', index_col=0)
rtns = np.log(prices).diff()

# %%
dvds = pd.read_excel('simul_20191210.xlsx', sheet_name='dvd', index_col=0)

# %% [markdown]
# # 초기전략: 최적화만 하는 경우

# %%
'''
변수설정
'''
n_dates = len(rtns)
n_cov = 12             # cov 계산 개월수

w_max = 0.10           # 종목 최대비중
w_us_min = 0.4         # 미국 최소비중
w_us_max = 0.8         # 미국 최대비중
w_ps_max = 0.1         # 우선주 최대비중
dvd_min = 2.5          # 포트폴리오 최소 배당수익률

n = len(rtns.columns)  # 종목수
w_p0 = np.zeros(n-3)   # 비중벡터 초기값

dates_rng = range(n_cov, n_dates)
weights = np.zeros((len(dates_rng), len(w_p0)))
result = {}


for i in tqdm_notebook(dates_rng):
    date = rtns.index[i]
    _rtns = rtns.iloc[i-11:i+1]
    dvd = dvds.iloc[i]
    
    investable = 1 - (dvd[:-2].isna() | _rtns.iloc[-1][1:-2].isna())
    bounds = list(zip(list(w_p0), list(w_p0 + w_max*investable)))
    
    # te 계산
    def te(w_p):
        w = np.zeros(n)
        w[1:-2] = w_p
        w[0] = 1
        cov = _rtns.cov(min_periods=n_cov/2).fillna(0)
        return w @ cov @ w

    # 비중합=0
    def sum_to_one(w_p):
        return 1 - w_p.sum()
    
    # 미국 최소비중
    def us_min(w_p):
        return w_p[:24].sum() - w_us_min

    # 미국 최대비중
    def us_max(w_p):
        return w_us_max - w_p[:24].sum()
    
    # 우선주 최대비중
    def ps_max(w_p):
        return w_ps_max - w_p[19:25].sum()

    # 포트폴리오 최소 배당수익률
    def dvd_sum_min(w_p):
        return dvd[:-2].fillna(0) @ w_p - dvd_min

    
    resp = fmin_slsqp(te, w_p0, 
                      eqcons=[sum_to_one], 
                      ieqcons=[us_min, us_max, ps_max, dvd_sum_min], 
                      bounds=bounds, iter=1000, full_output=True, iprint=0)
    
    if resp[3]==0:
        pos = resp[0]
        weights[i-n_cov,:] = pos
        
        result[date] = {
            'te': resp[1]**0.5, 
            'w_total': pos.sum(),
            'w_us': pos[:24].sum(),
            'dvd': dvd_sum_min(pos) + dvd_min, 
        }
        
    else:
        print(date, resp[-1])
# Out:
# HBox(children=(IntProgress(value=0, max=108), HTML(value='')))

# %%
df_result = pd.DataFrame(result).T; df_result
# Out:
#                  dvd        te  w_total      w_us
# 2010-12-31  3.544815  0.104448      1.0  0.800000
# 2011-01-31  3.560929  0.100125      1.0  0.800000
# 2011-02-28  3.487667  0.100347      1.0  0.800000
# 2011-03-31  3.479074  0.097373      1.0  0.800000
# 2011-04-29  3.386458  0.098990      1.0  0.800000
# 2011-05-31  3.385532  0.075995      1.0  0.800000
# 2011-06-30  3.227141  0.072325      1.0  0.800000
# 2011-07-29  3.061570  0.062068      1.0  0.800000
# 2011-08-31  3.270170  0.064637      1.0  0.800000
# 2011-09-30  3.657158  0.066681      1.0  0.800000
# 2011-10-31  3.544824  0.078013      1.0  0.800000
# 2011-11-30  3.563303  0.075180      1.0  0.800000
# 2011-12-30  3.493964  0.071631      1.0  0.800000
# 2012-01-31  3.256474  0.072178      1.0  0.800000
# 2012-02-29  3.163130  0.073429      1.0  0.800000
# 2012-03-30  3.351706  0.073221      1.0  0.800000
# 2012-04-30  3.347173  0.069197      1.0  0.800000
# 2012-05-31  3.669454  0.079689      1.0  0.800000
# 2012-06-29  3.750137  0.085208      1.0  0.800000
# 2012-07-31  3.779856  0.084305      1.0  0.800000
# 2012-08-31  3.856055  0.080931      1.0  0.800000
# 2012-09-28  3.816071  0.068257      1.0  0.800000
# 2012-10-31  3.963471  0.057425      1.0  0.800000
# 2012-11-30  3.823599  0.054334      1.0  0.800000
# 2012-12-31  4.063977  0.054441      1.0  0.800000
# 2013-01-31  3.628835  0.057604      1.0  0.800000
# 2013-02-28  3.511917  0.055225      1.0  0.800000
# 2013-03-29  2.865094  0.055039      1.0  0.800000
# 2013-04-30  2.527029  0.054519      1.0  0.800000
# 2013-05-31  2.578681  0.035450      1.0  0.799479
# ...              ...       ...      ...       ...
# 2017-06-30  3.489378  0.029203      1.0  0.758990
# 2017-07-31  3.446015  0.027169      1.0  0.758921
# 2017-08-31  3.455168  0.026620      1.0  0.758927
# 2017-09-29  3.452429  0.027284      1.0  0.758859
# 2017-10-31  3.460080  0.017099      1.0  0.758783
# 2017-11-30  3.375900  0.017404      1.0  0.757980
# 2017-12-29  3.373933  0.016101      1.0  0.766991
# 2018-01-31  3.304568  0.020352      1.0  0.767629
# 2018-02-28  3.545969  0.035191      1.0  0.787328
# 2018-03-30  3.987411  0.036330      1.0  0.790908
# 2018-04-30  4.029801  0.036386      1.0  0.798032
# 2018-05-31  4.031935  0.038525      1.0  0.800000
# 2018-06-29  4.178846  0.038466      1.0  0.795182
# 2018-07-31  4.234473  0.040525      1.0  0.770642
# 2018-08-31  4.238652  0.040366      1.0  0.786769
# 2018-09-28  4.360379  0.039075      1.0  0.800000
# 2018-10-31  4.744687  0.048712      1.0  0.800000
# 2018-11-30  4.730479  0.048231      1.0  0.800000
# 2018-12-31  4.693269  0.061265      1.0  0.702280
# 2019-01-31  4.202649  0.070308      1.0  0.699097
# 2019-02-28  4.210134  0.066112      1.0  0.767882
# 2019-03-29  4.279189  0.065737      1.0  0.771102
# 2019-04-30  4.205465  0.066234      1.0  0.783008
# 2019-05-31  4.464822  0.073485      1.0  0.677507
# 2019-06-28  4.360864  0.079837      1.0  0.636119
# 2019-07-31  4.395097  0.078101      1.0  0.642679
# 2019-08-30  4.457073  0.079143      1.0  0.641492
# 2019-09-30  4.269938  0.081572      1.0  0.657844
# 2019-10-31  4.152526  0.074587      1.0  0.520177
# 2019-11-29  4.061794  0.074300      1.0  0.560433
#
# [108 rows x 4 columns]

# %%
df_w = pd.DataFrame(weights, index=df_result.index, columns=dvds.columns[:-2]).shift(1); df_w;

# %%
df_rtns = rtns.loc[df_result.index, dvds.columns[:-2]]; df_rtns;

# %%
cum_port0 = (df_w*df_rtns).sum(axis=1).cumsum()

# %%
cum_bm = rtns.loc[df_result.index]['M1ACWIHD INDEX']
cum_bm.iloc[0] = 0
cum_bm = cum_bm.cumsum()

# %%
cum = np.exp(pd.DataFrame({'port_0':cum_port0, 'bm':cum_bm}))
cum.plot()

# %%
std = cum.pct_change().std()*(12**0.5)
cagr = cum.iloc[-1]**(12/(len(cum)-1))-1
rar = cagr/std
stats = pd.DataFrame({'cagr':cagr, 'std':std, 'rar':rar}); stats
# Out:
#             cagr       std       rar
# port_0  0.093935  0.093304  1.006768
# bm      0.072373  0.112851  0.641317

# %% [markdown]
# # 모멘텀 종목 고르는 경우

# %%
'''
변수설정
'''
n_dates = len(rtns)

n_filter = 0.5         # 모멘텀 상위 50%만 선택
n_cov = 12             # cov 계산 개월수

w_max = 0.10           # 종목 최대비중
w_us_min = 0.4         # 미국 최소비중
w_us_max = 0.8         # 미국 최대비중
w_ps_max = 0.1         # 우선주 최대비중
dvd_min = 2.5          # 포트폴리오 최소 배당수익률

n = len(rtns.columns)  # 종목수
w_p0 = np.zeros(n-3)   # 비중벡터 초기값

dates_rng = range(n_cov, n_dates)
weights = np.zeros((len(dates_rng), len(w_p0)))
result = {}


# 모멘텀 종목 걸러내기
def has_momentum(rt):
    univ['momentum'] = rt.iloc[-3:].sum(min_count=2)[1:-2].values
    return univ.groupby('category')['momentum'].rank(ascending=False, pct=True, na_option='bottom') <= n_filter


for i in tqdm_notebook(dates_rng):
    date = rtns.index[i]
    _rtns = rtns.iloc[i-11:i+1]
    dvd = dvds.iloc[i]
    
    investable = 1 - (dvd[:-2].isna() | _rtns.iloc[-1][1:-2].isna())
    investable = investable.values * has_momentum(_rtns)
    bounds = list(zip(list(w_p0), list(w_p0 + w_max*investable)))
    
    # te 계산
    def te(w_p):
        w = np.zeros(n)
        w[1:-2] = w_p
        w[0] = 1
        cov = _rtns.cov(min_periods=n_cov/2).fillna(0)
        return w @ cov @ w

    # 비중합=0
    def sum_to_one(w_p):
        return 1 - w_p.sum()
    
    # 미국 최소비중
    def us_min(w_p):
        return w_p[:24].sum() - w_us_min

    # 미국 최대비중
    def us_max(w_p):
        return w_us_max - w_p[:24].sum()
    
    # 우선주 최대비중
    def ps_max(w_p):
        return w_ps_max - w_p[19:25].sum()

    # 포트폴리오 최소 배당수익률
    def dvd_sum_min(w_p):
        return dvd[:-2].fillna(0) @ w_p - dvd_min


    resp = fmin_slsqp(te, w_p0, 
                      eqcons=[sum_to_one], 
                      ieqcons=[us_min, us_max, ps_max, dvd_sum_min], 
                      bounds=bounds, iter=1000, full_output=True, iprint=0)
    
    
    # 최적화 성공한다면:
    if resp[3]==0:
        pos = resp[0]
        weights[i-n_cov,:] = pos
        
        result[date] = {
            'te': resp[1]**0.5, 
            'w_total': pos.sum(),
            'w_us': pos[:24].sum(),
            'dvd': dvd_sum_min(pos) + dvd_min, 
        }
        
    # 최적화 실패한다면:
    else:
        print(date, resp[-1])
        pos = resp[0]
        weights[i-n_cov,:] = pos
        
        result[date] = {
            'te': resp[1]**0.5, 
            'w_total': pos.sum(),
            'w_us': pos[:24].sum(),
            'dvd': dvd_sum_min(pos) + dvd_min, 
        }
# Out:
# HBox(children=(IntProgress(value=0, max=108), HTML(value='')))
# 2011-05-31 00:00:00 Inequality constraints incompatible

# %%
df_result = pd.DataFrame(result).T; df_result
# Out:
#                  dvd        te  w_total      w_us
# 2010-12-31  3.380656  0.106102      1.0  0.800000
# 2011-01-31  3.326340  0.102466      1.0  0.800000
# 2011-02-28  3.460000  0.103554      1.0  0.800000
# 2011-03-31  3.392350  0.101219      1.0  0.800000
# 2011-04-29  3.400054  0.102661      1.0  0.800000
# 2011-05-31  3.058640  0.074047      0.9  0.700000
# 2011-06-30  3.365710  0.073851      1.0  0.800000
# 2011-07-29  3.487802  0.066672      1.0  0.800000
# 2011-08-31  3.593849  0.070060      1.0  0.800000
# 2011-09-30  4.039613  0.072561      1.0  0.800000
# 2011-10-31  3.824600  0.085848      1.0  0.800000
# 2011-11-30  3.861870  0.082859      1.0  0.800000
# 2011-12-30  3.627910  0.080379      1.0  0.800000
# 2012-01-31  3.117873  0.077753      1.0  0.800000
# 2012-02-29  3.056219  0.082927      1.0  0.800000
# 2012-03-30  3.168463  0.082393      1.0  0.800000
# 2012-04-30  3.430267  0.076193      1.0  0.800000
# 2012-05-31  3.870530  0.079627      1.0  0.800000
# 2012-06-29  3.966474  0.086525      1.0  0.800000
# 2012-07-31  3.976363  0.086853      1.0  0.800000
# 2012-08-31  3.744688  0.087601      1.0  0.800000
# 2012-09-28  3.562932  0.073792      1.0  0.800000
# 2012-10-31  3.546661  0.060392      1.0  0.800000
# 2012-11-30  3.773332  0.060093      1.0  0.800000
# 2012-12-31  3.448918  0.057981      1.0  0.800000
# 2013-01-31  3.301959  0.060675      1.0  0.800000
# 2013-02-28  3.706004  0.057883      1.0  0.800000
# 2013-03-29  3.668303  0.057388      1.0  0.800000
# 2013-04-30  3.530923  0.058471      1.0  0.800000
# 2013-05-31  3.160249  0.038714      1.0  0.800000
# ...              ...       ...      ...       ...
# 2017-06-30  3.378682  0.028298      1.0  0.755045
# 2017-07-31  3.127453  0.027326      1.0  0.754844
# 2017-08-31  3.379051  0.025749      1.0  0.786800
# 2017-09-29  3.152771  0.028618      1.0  0.786962
# 2017-10-31  3.172962  0.016824      1.0  0.754938
# 2017-11-30  3.160970  0.017175      1.0  0.754442
# 2017-12-29  2.929331  0.017086      1.0  0.786582
# 2018-01-31  3.198548  0.021817      1.0  0.754611
# 2018-02-28  3.243831  0.036885      1.0  0.771171
# 2018-03-30  3.457627  0.039428      1.0  0.765602
# 2018-04-30  4.394812  0.039057      1.0  0.760595
# 2018-05-31  4.310097  0.039262      1.0  0.762628
# 2018-06-29  4.517673  0.040046      1.0  0.760386
# 2018-07-31  3.694923  0.043562      1.0  0.767538
# 2018-08-31  3.236222  0.045589      1.0  0.800000
# 2018-09-28  3.639315  0.044719      1.0  0.800000
# 2018-10-31  3.895536  0.053291      1.0  0.800000
# 2018-11-30  4.123509  0.052490      1.0  0.800000
# 2018-12-31  4.192250  0.063842      1.0  0.800000
# 2019-01-31  3.822820  0.073439      1.0  0.800000
# 2019-02-28  3.818625  0.069542      1.0  0.800000
# 2019-03-29  3.557587  0.070605      1.0  0.800000
# 2019-04-30  3.328658  0.070028      1.0  0.800000
# 2019-05-31  3.661509  0.075986      1.0  0.800000
# 2019-06-28  3.650218  0.083502      1.0  0.800000
# 2019-07-31  4.047888  0.080414      1.0  0.800000
# 2019-08-30  3.979730  0.082091      1.0  0.800000
# 2019-09-30  4.230100  0.084209      1.0  0.749254
# 2019-10-31  4.111185  0.076491      1.0  0.700000
# 2019-11-29  3.598794  0.078672      1.0  0.700000
#
# [108 rows x 4 columns]

# %%
df_w = pd.DataFrame(weights, index=df_result.index, columns=dvds.columns[:-2]).shift(1)

# %%
df_rtns = rtns.loc[df_result.index, dvds.columns[:-2]]

# %%
cum_port1 = (df_w*df_rtns).sum(axis=1).cumsum()

# %%
cum_bm = rtns.loc[df_result.index]['M1ACWIHD INDEX']
cum_bm.iloc[0] = 0
cum_bm = cum_bm.cumsum()

# %%
cum = np.exp(pd.DataFrame({'port_1':cum_port1, 'port_0':cum_port0, 'bm':cum_bm}))
cum.plot()

# %%
std = cum.pct_change().std()*(12**0.5)
cagr = cum.iloc[-1]**(12/(len(cum)-1))-1
rar = cagr/std
stats = pd.DataFrame({'cagr':cagr, 'std':std, 'rar':rar}); stats
# Out:
#             cagr       std       rar
# port_1  0.101060  0.090741  1.113727
# port_0  0.093935  0.093304  1.006768
# bm      0.072373  0.112851  0.641317

# %% [markdown]
# # BM 모멘텀이 안나올때 UST 편입하는 경우

# %%
df_bm_rtns = rtns['M1ACWIHD INDEX'].rolling(3).sum().loc[df_result.index]

# %%
UST = 'SHY'

# %%
df_w_append = df_w.copy()
for date, val in df_bm_rtns.items():
    if val<0:
        df_w_append.loc[date] *= 0.8
        df_w_append.loc[date, UST] = 0.2

# %%
df_rtns[UST] = rtns.loc[df_result.index, UST]

# %%
cum_port2 = (df_w_append*df_rtns).sum(axis=1).cumsum()

# %%
cum_bm = rtns.loc[df_result.index]['M1ACWIHD INDEX']
cum_bm.iloc[0] = 0
cum_bm = cum_bm.cumsum()

# %%
cum = np.exp(pd.DataFrame({'port_2':cum_port2, 'port_1':cum_port1, 'port_0':cum_port0, 'bm':cum_bm}))
cum.plot()

# %%
std = cum.pct_change().std()*(12**0.5)
cagr = cum.iloc[-1]**(12/(len(cum)-1))-1
rar = cagr/std
stats = pd.DataFrame({'cagr':cagr, 'std':std, 'rar':rar}); stats
# Out:
#             cagr       std       rar
# port_2  0.106371  0.081257  1.309079
# port_1  0.101060  0.090741  1.113727
# port_0  0.093935  0.093304  1.006768
# bm      0.072373  0.112851  0.641317

# %%
df_w.iloc[-1][df_w.iloc[-1]>0]
# Out:
# VYM     0.051250
# FDL     0.080117
# SCHD    0.039323
# FVD     0.100000
# DHS     0.055602
# DIV     0.100000
# NOBL    0.100000
# DGRO    0.073709
# FPE     0.066160
# VRP     0.033840
# VYMI    0.100000
# DEM     0.100000
# IDV     0.100000
# Name: 2019-11-29 00:00:00, dtype: float64

# %%
df_result.dvd.plot(color='orange', figsize=(5,4), ylim=(0,5))

# %%
df_result.te.plot()

# %%
perf = np.exp(pd.DataFrame({'HGDM':cum_port2, 'MSCI AC High Div Index (BM)':cum_bm}))

# %%
ax = perf.plot(figsize=(10,4), color=['orange','gray'])
ax.legend(fontsize=13)

# %%
ytd = perf.iloc[-1]/perf.loc['2018-12-31']-1
r3m = perf.iloc[-1]/perf.iloc[-4]-1
r1y = perf.iloc[-1]/perf.iloc[-13]-1
r3y = perf.iloc[-1]/perf.iloc[-37]-1

# %%
pd.DataFrame({'ytd':ytd, '1y':r1y, '3y':r3y})
# Out:
#                                   ytd        1y        3y
# HGDM                         0.201752  0.140774  0.377961
# MSCI AC High Div Index (BM)  0.193120  0.122125  0.353101
