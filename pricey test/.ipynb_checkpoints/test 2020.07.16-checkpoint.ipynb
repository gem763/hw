# %%
import pandas as pd
import numpy as np

# %%
rng = [20]
relperf = {
    'm3': pd.read_pickle('relperf3m.pkl')[rng].mean(axis=1),
    'm6': pd.read_pickle('relperf6m.pkl')[rng].mean(axis=1),
    'y1': pd.read_pickle('relperf1y.pkl')[rng].mean(axis=1),
    'y2': pd.read_pickle('relperf2y.pkl')[rng].mean(axis=1),
    'y3': pd.read_pickle('relperf3y.pkl')[rng].mean(axis=1),
    'y4': pd.read_pickle('relperf4y.pkl')[rng].mean(axis=1),
    'y5': pd.read_pickle('relperf5y.pkl')[rng].mean(axis=1)
}

relperf = pd.DataFrame(relperf)

# %%
relperf
# Out:
#                   m3        m6        y1        y2        y3        y4  \
# 2009-10-02  0.082947  0.058180  0.086958 -0.147710 -0.497271 -0.287424
# 2009-10-09  0.042586  0.031564  0.121703 -0.221146 -0.338589 -0.238273
# 2009-10-16  0.504207  0.382217  0.245406 -0.153113  0.190222  0.252728
# 2009-10-23  0.481651  0.356384  0.269256  0.029588  0.429412  0.214581
# 2009-10-30  0.799279  0.649536  0.545122  0.636957  0.669939  0.446305
# ...              ...       ...       ...       ...       ...       ...
# 2019-06-07 -0.582341 -0.715460  0.859490  0.844325  0.298349 -0.040579
# 2019-06-14 -0.761858 -0.598630  0.678115  0.596995  0.255941 -0.073995
# 2019-06-21 -0.148869 -0.282467  0.516998  0.539071  0.449344  0.461906
# 2019-06-28  0.093707  0.553255  0.773456  0.811131  0.690898  0.692583
# 2019-07-05  0.633685 -0.172425 -0.622104 -0.481253 -0.579913 -0.342883
#
#                   y5
# 2009-10-02 -0.126900
# 2009-10-09  0.060917
# 2009-10-16  0.346259
# 2009-10-23  0.327878
# 2009-10-30  0.199104
# ...              ...
# 2019-06-07 -0.488537
# 2019-06-14 -0.506321
# 2019-06-21 -0.224130
# 2019-06-28  0.034002
# 2019-07-05  0.437500
#
# [510 rows x 7 columns]

# %%
selection_strat = relperf[relperf>=0.5].idxmax(axis=1)
# selection_strat = relperf.idxmax(axis=1)
# selection_strat = relperf.rolling(1).sum().idxmax(axis=1)

result = []

for date, val in selection_strat.shift(1).items():
    try:
        result.append((date, relperf.loc[date, val]))
    except:
        pass
    
result = pd.Series(dict(result))

# %%
result
# Out:
# 2009-10-23    0.481651
# 2009-11-06    0.482641
# 2009-11-13    0.289499
# 2009-12-04    0.088890
# 2009-12-18    0.811176
#                 ...
# 2019-06-07    0.859490
# 2019-06-14    0.678115
# 2019-06-21    0.516998
# 2019-06-28    0.811131
# 2019-07-05   -0.481253
# Length: 256, dtype: float64

# %%
print(result.mean(), relperf['y1'].mean())
relperf['y1'].plot(label='y1', legend=True)
result.plot(label='sel_max', legend=True)
# Out:
# 0.45087921941129583 0.015621791402648402
